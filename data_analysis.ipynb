# %% [markdown]
# Write here text.

# %%
import pandas as pd

# %%
df = pd.read_excel('data/Data_EuroStoxx.xlsx', index_col='Time')
df.head()
# Out:
#             NaN                                         #ERROR  \
# Time
# 1988-02-27  NaN  $$ER: E100,INVALID CODE OR EXPRESSION ENTERED
# 1988-03-27  NaN                                            NaN
# 1988-04-27  NaN                                            NaN
# 1988-05-27  NaN                                            NaN
# 1988-06-27  NaN                                            NaN
#
#             EURO STOXX 50 - MARKET VALUE  EURO STOXX 50 - DIVIDEND YIELD  \
# Time
# 1988-02-27                           NaN                             NaN
# 1988-03-27                           NaN                             NaN
# 1988-04-27                           NaN                             NaN
# 1988-05-27                           NaN                             NaN
# 1988-06-27                           NaN                             NaN
#
#             EURO STOXX 50 - TOT RETURN IND  \
# Time
# 1988-02-27                             NaN
# ...
